# %% [markdown]
# # Projeto 1 - Aprendizado não supervisionado - Detecção de outliers

# %% [markdown]
# ### Pacotes necesários

# %%
import Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("ScikitLearn")
Pkg.add("Clustering")
Pkg.add("Distances")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\david\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\david\.julia\environments\v1.10\Manifest.toml`
# Precompiling project...
#     JuliaFormatter Being precompiled by another process (pid: 12016, pidfile: C:\Users\david\.julia\compiled\v1.10\JuliaFormatter\OWZnm_iW4iT.ji.pidfile)
#   ✓ JuliaFormatter
#   1 dependency successfully precompiled in 50 seconds. 220 already precompiled.
#    Resolving package versions...
#   No Changes to `C:\Users\david\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\david\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\david\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\david\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\david\.julia\environments\v1.10\Project.toml`
# ...

# %%
using CSV, DataFrames, ScikitLearn, Clustering, Distances, Statistics

# %%
dados = CSV.File(read("dados1/dataset.csv")) |> DataFrame
# Out:
# 8525×27 DataFrame
#   Row │ tumorsize  co2      pain   wound  mobility  ntumors  nmorphine  remiss ⋯
#       │ Float64    Float64  Int64  Int64  Int64     Int64    Int64      Int64  ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │   67.9812  1.53433      4      4         2        0          0         ⋯
#     2 │   64.7025  1.67613      2      3         2        0          0
#     3 │   51.567   1.53345      6      3         2        0          0
#     4 │   86.438   1.4533       3      3         2        0          0
#     5 │   53.4002  1.56635      3      4         2        0          0         ⋯
#     6 │   51.6573  1.41787      4      5         2        0          0
#     7 │   78.9171  1.70663      3      4         2        0          0
#     8 │   69.8332  1.52873      3      3         3        0          0
#   ⋮   │     ⋮         ⋮       ⋮      ⋮       ⋮         ⋮         ⋮          ⋮  ⋱
# ...

# %%
println("Linhas : ",size(dados)[1])
println("Colunas: ",size(dados)[2])
# Out:
# Linhas : 8525
# Colunas: 27

# %%
show(dados, allcols = true)
# Out:
# 8525×27 DataFrame
#   Row │ tumorsize  co2      pain   wound  mobility  ntumors  nmorphine  remission  lungcapacity  Age      Married  FamilyHx  SmokingHx  Sex      CancerStage  LengthofStay  WBC      RBC      BMI      IL6        CRP        DID    Experience  School   Lawsuits  HID    Medicaid
#       │ Float64    Float64  Int64  Int64  Int64     Int64    Int64      Int64      Float64       Float64  Int64    String3   String7    String7  String3      Int64         Float64  Float64  Float64  Float64    Float64    Int64  Int64       String7  Int64     Int64  Float64
# ──────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...

# %%
@sk_import preprocessing: LabelEncoder
# Out:
# ┌ Info: Installing sklearn via the Conda scikit-learn>=1.2,<1.3 package...
# └ @ PyCall C:\Users\david\.julia\packages\PyCall\1gn3u\src\PyCall.jl:719
# ┌ Info: Running `conda config --add channels conda-forge --file 'C:\Users\david\.julia\conda\3\x86_64\condarc-julia.yml' --force` in root environment
# └ @ Conda C:\Users\david\.julia\packages\Conda\zReqD\src\Conda.jl:181
# ...
# ┌ Info: Running `conda install -y 'scikit-learn>=1.2,<1.3'` in root environment
# └ @ Conda C:\Users\david\.julia\packages\Conda\zReqD\src\Conda.jl:181
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working...
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# failed
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - package scikit-learn-1.2.0-py310had3394f_0 requires python >=3.10,<3.11.0a0, but none of the providers can be installed
#
# Could not solve for environment specs
# The following packages are incompatible
# ...

# %%
Encod = LabelEncoder()
# Out:
# UndefVarError: `LabelEncoder` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\david\Desktop\Formacao_Engenheiro_inteligencia_artificial\8-DS_e_ML_com_Julia\JuliaLanguage\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:1
